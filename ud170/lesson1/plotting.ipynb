# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

vals = np.random.random_integers(1,6,10)
plt.plot(vals)
# Out:
# Populating the interactive namespace from numpy and matplotlib
